# %% [markdown]
# # 1

# %%
'''
Flask Framework is a micro web framework written in Python that allows developers to build web applications quickly and easily.
It is a lightweight framework that provides essential tools and features for web development,
such as URL routing, templates, and request handling. Flask is highly customizable and can be 
extended with various third-party libraries, making it a popular choice for web development.

The advantages of Flask Framework include:

Minimalism: Flask is a minimalistic framework that allows developers to build web applications quickly and with fewer lines of code.
Flexibility: Flask is highly flexible and can be extended with various third-party libraries and tools to meet specific project requirements.
Easy to learn: Flask has a simple and intuitive syntax that makes it easy for beginners to learn and start developing web applications.
Modular: Flask follows a modular design, allowing developers to choose and use only the components they need for their application.
Lightweight: Flask is a lightweight framework that requires fewer resources and can run on low-end hardware
'''

# %% [markdown]
# # 2

# %% [markdown]
# ![q2.png](attachment:85aadb9f-f47a-47ae-b2d9-cf74a27636a0.png)

# %% [markdown]
# # 3

# %%
'''
App routing in Flask is the process of mapping URL patterns to view functions in a Flask application. 
We use app routes to define the URL patterns and associate them with specific view functions that handle the requests.
App routes allow us to create a modular and organized URL structure for our application, making it easy to manage and maintain.
App routes also provide a simple and intuitive way to handle different HTTP methods, such as GET and POST.
'''

# %% [markdown]
# # 4

# %% [markdown]
# ![Screenshot 2023-02-19 231803.png](attachment:dac452e9-352c-47ae-b2cf-a812609e992c.png)

# %% [markdown]
# ![3.png](attachment:c6f26a3d-909c-4f89-8737-ba2d90ba04df.png)

# %% [markdown]
# # 5

# %%
'''
The url_for() function is used in Flask for URL building. It takes the name of a view function and generates
a URL that maps to it.
Here's an example code that demonstrates the working of the url_for() function:
'''
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def hello():
    return 'Hello World!!'

@app.route('/user/<username>')
def user(username):
    return f'Hello, {username}!'

if __name__ == '__main__':
    with app.test_request_context():
        print(url_for('hello')) # Output: /
        print(url_for('user', username='aditya'))
        
# Output: /user/aditya
